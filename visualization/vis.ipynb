# %%
# Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import open3d as o3d  # Uncomment if using Open3D

# Load NPZ File
npz_data = np.load('/home/cs236finalproject/diffFactoCS236/diffFacto/work_dirs/gen_chair/val/gen_fixed0000_chair_1250.npz')
print(list(npz_data.keys()))
point_cloud = npz_data['anchors']  # Or the appropriate key

# Data Processing (if necessary)
# ... Your processing code ...

# Visualization with Matplotlib
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(point_cloud[:, 0], point_cloud[:, 1], point_cloud[:, 2])
plt.show()

# Visualization with Open3D (if using Open3D)
# pcd = o3d.geometry.PointCloud()
# pcd.points = o3d.utility.Vector3dVector(point_cloud)
# o3d.visualization.draw_geometries([pcd])
# Out:
# ['100_sample 0', '90_sample 0', '80_sample 0', '70_sample 0', '60_sample 0', '50_sample 0', '40_sample 0', '30_sample 0', '20_sample 0', '10_sample 0', 'pred_sample 0', 'sample prior 0', 'pred', 'pred_seg_mask', 'anchors', 'input', 'input_ref', 'ref_seg_mask', 'seg_mask', 'present', 'shift', 'scale']

# %%
from visualization.utils.general import *
from visualization.gif_maker import make_gif
from visualization.visualizer_pkl import visualize_pkl


out = np.load('/home/cs236finalproject/diffFactoCS236/diffFacto/work_dirs/gen_chair/val/gen_fixed0000_chair_1250.npz')
out = dict(out)
visualize_pkl(out, 0)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# ['100_sample 0', '90_sample 0', '80_sample 0', '70_sample 0', '60_sample 0', '50_sample 0', '40_sample 0', '30_sample 0', '20_sample 0', '10_sample 0', 'pred_sample 0', 'sample prior 0', 'pred', 'pred_seg_mask', 'anchors', 'input', 'input_ref', 'ref_seg_mask', 'seg_mask', 'present', 'shift', 'scale']
# 128
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       6 out = np.load('/home/cs236finalproject/diffFactoCS236/diffFacto/work_dirs/gen_chair/val/gen_fixed0000_chair_1250.npz')
#       7 out = dict(out)
# ----> 8 visualize_pkl(out, 0)
#
# File ~/diffFactoCS236/visualization/visualizer_pkl.py:41, in visualize_pkl(out, exp_num, interpolate_params, assigned_anchor)
# ...

# %%
# !python visualization/visualizer.py /home/cs236finalproject/diffFactoCS236/diffFacto/work_dirs/gen_chair/val/gen_fixed0000_chair_1250.npz
# Out:
# ['100_sample 0', '90_sample 0', '80_sample 0', '70_sample 0', '60_sample 0', '50_sample 0', '40_sample 0', '30_sample 0', '20_sample 0', '10_sample 0', 'pred_sample 0', 'sample prior 0', 'pred', 'pred_seg_mask', 'anchors', 'input', 'input_ref', 'ref_seg_mask', 'seg_mask', 'present', 'shift', 'scale']
# 128
# Traceback (most recent call last):
#   File "/home/cs236finalproject/diffFactoCS236/visualization/visualizer.py", line 107, in <module>
#     visualize_pkl(out, 0, args.params)
#   File "/home/cs236finalproject/diffFactoCS236/visualization/visualizer_pkl.py", line 41, in visualize_pkl
#     pcd.colors = o3d.utility.Vector3dVector(utils.normalize(pc))
# NameError: name 'utils' is not defined

# %%
# !pwd
# Out:
# /home/cs236finalproject/diffFactoCS236
